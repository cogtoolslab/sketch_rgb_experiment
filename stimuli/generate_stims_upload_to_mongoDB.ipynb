# %% [markdown]
# ### this notebook is to generate stims for graph-comprehension-benchmarking
# Before this notebook, `gcb_data.csv` was manually generated by selecting the original stimuli data from the VLAT and GGR papers

# %%
## generally useful
import os
import numpy as np
import pandas as pd
import pymongo as pm
from glob import glob
import json
import ast

## handling communication with Amazon Web Services using Python
import boto3 
import botocore

## general jupyter notebook utilities
from IPython.display import clear_output

## image downloading & processing
from PIL import Image
import requests
from io import BytesIO

# %%
# directory & file hierarchy
proj_dir = os.path.abspath('..')
stimuli_dir = os.getcwd()

# %% [markdown]
# ### load data

# %%
## load in pre-generated metadata CSV file
data = {
    "0": {
        "class": "rabbit",
        "photo_id": 0,
        "sketch_id": 0,
        "keypoint_id": 0,
        "url1": "https://sketchy.eye.gatech.edu/explore/photos/rabbit/n02325366_10628.jpg",
        "url2": "https://sketchy.eye.gatech.edu/explore/sketches/rabbit/n02325366_10628-1.png",
        "trial_num": "25",
        "trial_seed": "1025",
        "zone_id": "1"
    },
    "1": {
        "class": "banana",
        "photo_id": 0,
        "sketch_id": 0,
        "keypoint_id": 0,
        "url1": "https://sketchy.eye.gatech.edu/explore/photos/banana/n07753592_10692.jpg",
        "url2": "https://sketchy.eye.gatech.edu/explore/sketches/banana/n07753592_10692-1.png",
        "trial_num": "6",
        "trial_seed": "5006",
        "zone_id": "1"
    },
    "2": {
        "class": "cat",
        "photo_id": 0,
        "sketch_id": 0,
        "keypoint_id": 0,
        "url1": "https://sketchy.eye.gatech.edu/explore/photos/cat/n02121620_11995.jpg",
        "url2": "https://sketchy.eye.gatech.edu/explore/sketches/cat/n02121620_11995-2.png",
        "trial_num": "14",
        "trial_seed": "4014",
        "zone_id": "1"
    },
    "3": {
        "class": "helicopter",
        "photo_id": 0,
        "sketch_id": 0,
        "keypoint_id": 0,
        "url1": "https://sketchy.eye.gatech.edu/explore/photos/helicopter/n03512147_1201.jpg",
        "url2": "https://sketchy.eye.gatech.edu/explore/sketches/helicopter/n03512147_1201-1.png",
        "trial_num": "20",
        "trial_seed": "5020",
        "zone_id": "1"
    },
}

meta = pd.DataFrame(data).transpose()
meta['experimentName'] = 'sketchy_test_split_human_keypoint'
meta['gcbID'] = 0

# %%
meta[0].to_json()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
# ----> 1 meta[0].to_json()
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3631, in Index.get_loc(self, key, method, tolerance)
#    3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
# -> 3631     raise KeyError(key) from err
#    3632 except TypeError:
#    3633     # If we have a listlike key, _check_indexing_error will raise
#    3634     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635     #  the TypeError.
#    3636     self._check_indexing_error(key)
#
# KeyError: 0

# %%
## make copy
final = meta.copy()

# %%
## initalize list of all version dictionaries
Meta = [] 

printed=False
for name, group in final.groupby('experimentName'): 
    display(name)
    print('Adding {} to Meta'.format(name)) 
    clear_output(wait=True)
    Batch = {} # initialize batch-level dictionary 
    Trials = [] # list of trials

    for n,g in group.groupby('gcbID'): # looping over trials within a batch
        stims = g.to_dict(orient='records')
        Trials.append(stims) 
    Batch['meta'] = Trials 
    Batch['games'] = []
    Meta.append(Batch)
    
# print('Done!')
# Out:
# 'sketchy_test_split_human_keypoint'
# Adding sketchy_test_split_human_keypoint to Meta

# %%
# Meta

# %%
## check how many Meta are being inserted
len(Meta)
# Out:
# 1

# %%
dataset_name = 'sketchy_test_split_input'
print('Saving out json dictionary out to file...') 
with open('{}_meta.js'.format(dataset_name), 'w') as fout:
    json.dump(Meta, fout)
print('Done!')
# Out:
# Saving out json dictionary out to file...
# Done!

# %%
#reload JSON back in to the new stimulus collection
J = json.loads(open('{}_meta.js'.format(dataset_name),mode='r').read())
print('dataset_name: {}'.format(dataset_name))
print('Length of J is: {}'.format(len(J)))
# Out:
# dataset_name: sketchy_test_split_input
# Length of J is: 1

# %% [markdown]
# ### insert metadata into mongo
# Run this command at the terminal, `ssh -fNL 27017:127.0.0.1:27017 hhuey@cogtoolslab.org`

# %%
# set vars 
auth = pd.read_csv('auth.txt', header = None) # this auth.txt file contains the password for the sketchloop user
pswd = auth.values[0][0]
user = 'cabUser'
host = 'cogtoolslab.org' ## cogtoolslab ip address

# have to fix this to be able to analyze from local
conn = pm.MongoClient('mongodb://cabUser:' + pswd + '@cogtoolslab.org')
print(conn)
db = conn['sketch_rgb_input'] ## everyone in the lab shares this stimulus database
coll = db["sketchy_test_split"]
coll
# Out:
# MongoClient(host=['cogtoolslab.org:27017'], document_class=dict, tz_aware=False, connect=True)
# Collection(Database(MongoClient(host=['cogtoolslab.org:27017'], document_class=dict, tz_aware=False, connect=True), 'sketch_rgb_input'), 'sketchy_test_split')

# %%
## now really insert data
reallyRun = True
if reallyRun:
    for (i,j) in enumerate(J):
        print ('%d of %d uploaded ...' % (i+1,len(J)))
        clear_output(wait=True)
        coll.insert_one(j)
print('Done!')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [37], in <cell line: 3>()
#       5         print ('%d of %d uploaded ...' % (i+1,len(J)))
#       6         clear_output(wait=True)
# ----> 7         coll.insert_one(j)
#       8 print('Done!')
#
# File ~/anaconda3/lib/python3.9/site-packages/pymongo/collection.py:621, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     617     document["_id"] = ObjectId()
#     619 write_concern = self._write_concern_for(session)
#     620 return InsertOneResult(
# --> 621     self._insert_one(
#     622         document,
#     623         ordered=True,
#     624         write_concern=write_concern,
#     625         op_id=None,
#     626         bypass_doc_val=bypass_document_validation,
#     627         session=session,
#     628         comment=comment,
#     629     ),
#     630     write_concern.acknowledged,
#     631 )
#
# File ~/anaconda3/lib/python3.9/site-packages/pymongo/collection.py:562, in Collection._insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     550     result = sock_info.command(
#     551         self.__database.name,
#     552         command,
#    (...)
#     557         retryable_write=retryable_write,
#     558     )
#     560     _check_write_command_response(result)
# --> 562 self.__database.client._retryable_write(acknowledged, _insert_command, session)
#     564 if not isinstance(doc, RawBSONDocument):
#     565     return doc.get("_id")
#
# File ~/anaconda3/lib/python3.9/site-packages/pymongo/mongo_client.py:1447, in MongoClient._retryable_write(self, retryable, func, session)
#    1445 def _retryable_write(self, retryable, func, session):
#    1446     """Internal retryable write helper."""
# -> 1447     with self._tmp_session(session) as s:
#    1448         return self._retry_with_session(retryable, func, s, None)
#
# File ~/anaconda3/lib/python3.9/contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     117 del self.args, self.kwds, self.func
#     118 try:
# --> 119     return next(self.gen)
#     120 except StopIteration:
#     121     raise RuntimeError("generator didn't yield") from None
#
# File ~/anaconda3/lib/python3.9/site-packages/pymongo/mongo_client.py:1729, in MongoClient._tmp_session(self, session, close)
#    1726     yield session
#    1727     return
# -> 1729 s = self._ensure_session(session)
#    1730 if s:
#    1731     try:
#
# File ~/anaconda3/lib/python3.9/site-packages/pymongo/mongo_client.py:1712, in MongoClient._ensure_session(self, session)
#    1707     return session
#    1709 try:
#    1710     # Don't make implicit sessions causally consistent. Applications
#    1711     # should always opt-in.
# -> 1712     return self.__start_session(True, causal_consistency=False)
#    1713 except (ConfigurationError, InvalidOperation):
#    1714     # Sessions not supported.
#    1715     return None
#
# File ~/anaconda3/lib/python3.9/site-packages/pymongo/mongo_client.py:1657, in MongoClient.__start_session(self, implicit, **kwargs)
#    1654 def __start_session(self, implicit, **kwargs):
#    1655     # Raises ConfigurationError if sessions are not supported.
#    1656     if implicit:
# -> 1657         self._topology._check_implicit_session_support()
#    1658         server_session = _EmptyServerSession()
#    1659     else:
#
# File ~/anaconda3/lib/python3.9/site-packages/pymongo/topology.py:538, in Topology._check_implicit_session_support(self)
#     536 def _check_implicit_session_support(self):
#     537     with self._lock:
# --> 538         self._check_session_support()
#
# File ~/anaconda3/lib/python3.9/site-packages/pymongo/topology.py:554, in Topology._check_session_support(self)
#     550         self._select_servers_loop(
#     551             any_server_selector, self.get_server_selection_timeout(), None
#     552         )
#     553 elif not self._description.readable_servers:
# --> 554     self._select_servers_loop(
#     555         readable_server_selector, self.get_server_selection_timeout(), None
#     556     )
#     558 session_timeout = self._description.logical_session_timeout_minutes
#     559 if session_timeout is None:
#
# File ~/anaconda3/lib/python3.9/site-packages/pymongo/topology.py:250, in Topology._select_servers_loop(self, selector, timeout, address)
#     244 self._request_check_all()
#     246 # Release the lock and wait for the topology description to
#     247 # change, or for a timeout. We won't miss any changes that
#     248 # came after our most recent apply_selector call, since we've
#     249 # held the lock until now.
# --> 250 self._condition.wait(common.MIN_HEARTBEAT_INTERVAL)
#     251 self._description.check_compatible()
#     252 now = time.monotonic()
#
# File ~/anaconda3/lib/python3.9/threading.py:316, in Condition.wait(self, timeout)
#     314 else:
#     315     if timeout > 0:
# --> 316         gotit = waiter.acquire(True, timeout)
#     317     else:
#     318         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
## check how many records were inserted
coll.estimated_document_count()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [27], in <cell line: 2>()
#       1 ## check how many records were inserted
# ----> 2 coll.estimated_document_count()
#
# File ~/anaconda3/lib/python3.9/site-packages/pymongo/collection.py:1750, in Collection.estimated_document_count(self, comment, **kwargs)
#    1747     cmd.update(kwargs)
#    1748     return self._count_cmd(session, sock_info, read_preference, cmd, collation=None)
# -> 1750 return self._retryable_non_cursor_read(_cmd, None)
#
# File ~/anaconda3/lib/python3.9/site-packages/pymongo/collection.py:1840, in Collection._retryable_non_cursor_read(self, func, session)
#    1838 """Non-cursor read helper to handle implicit session creation."""
#    1839 client = self.__database.client
# -> 1840 with client._tmp_session(session) as s:
#    1841     return client._retryable_read(func, self._read_preference_for(s), s)
#
# File ~/anaconda3/lib/python3.9/contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     117 del self.args, self.kwds, self.func
#     118 try:
# --> 119     return next(self.gen)
#     120 except StopIteration:
#     121     raise RuntimeError("generator didn't yield") from None
#
# File ~/anaconda3/lib/python3.9/site-packages/pymongo/mongo_client.py:1729, in MongoClient._tmp_session(self, session, close)
#    1726     yield session
#    1727     return
# -> 1729 s = self._ensure_session(session)
#    1730 if s:
#    1731     try:
#
# File ~/anaconda3/lib/python3.9/site-packages/pymongo/mongo_client.py:1712, in MongoClient._ensure_session(self, session)
#    1707     return session
#    1709 try:
#    1710     # Don't make implicit sessions causally consistent. Applications
#    1711     # should always opt-in.
# -> 1712     return self.__start_session(True, causal_consistency=False)
#    1713 except (ConfigurationError, InvalidOperation):
#    1714     # Sessions not supported.
#    1715     return None
#
# File ~/anaconda3/lib/python3.9/site-packages/pymongo/mongo_client.py:1657, in MongoClient.__start_session(self, implicit, **kwargs)
#    1654 def __start_session(self, implicit, **kwargs):
#    1655     # Raises ConfigurationError if sessions are not supported.
#    1656     if implicit:
# -> 1657         self._topology._check_implicit_session_support()
#    1658         server_session = _EmptyServerSession()
#    1659     else:
#
# File ~/anaconda3/lib/python3.9/site-packages/pymongo/topology.py:538, in Topology._check_implicit_session_support(self)
#     536 def _check_implicit_session_support(self):
#     537     with self._lock:
# --> 538         self._check_session_support()
#
# File ~/anaconda3/lib/python3.9/site-packages/pymongo/topology.py:554, in Topology._check_session_support(self)
#     550         self._select_servers_loop(
#     551             any_server_selector, self.get_server_selection_timeout(), None
#     552         )
#     553 elif not self._description.readable_servers:
# --> 554     self._select_servers_loop(
#     555         readable_server_selector, self.get_server_selection_timeout(), None
#     556     )
#     558 session_timeout = self._description.logical_session_timeout_minutes
#     559 if session_timeout is None:
#
# File ~/anaconda3/lib/python3.9/site-packages/pymongo/topology.py:250, in Topology._select_servers_loop(self, selector, timeout, address)
#     244 self._request_check_all()
#     246 # Release the lock and wait for the topology description to
#     247 # change, or for a timeout. We won't miss any changes that
#     248 # came after our most recent apply_selector call, since we've
#     249 # held the lock until now.
# --> 250 self._condition.wait(common.MIN_HEARTBEAT_INTERVAL)
#     251 self._description.check_compatible()
#     252 now = time.monotonic()
#
# File ~/anaconda3/lib/python3.9/threading.py:316, in Condition.wait(self, timeout)
#     314 else:
#     315     if timeout > 0:
# --> 316         gotit = waiter.acquire(True, timeout)
#     317     else:
#     318         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
## inspect one of these annotation sessions
coll.find_one()
# Out:
# {'_id': ObjectId('6275991bcfb15b1f96f61375'),
#  'meta': [[{'gcbID': 'item_1',
#     'chart_cat': 'bar_chart_level_1',
#     'origStudy': 'GGR',
#     'blockNum': 1,
#     'origStudy_order_num': 'q_01',
#     'prompt': 'What percentage of patients recovered after chemotherapy?',
#     'options': ['write your answer'],
#     'corrAns': '“35” , “35%”',
#     'graphType': 'bar_chart',
#     'origStudy_taskCategorization': 'level_1',
#     'promptTitle': 'Here is some information about cancer therapies',
#     'questionType': 'fill_in_blank',
#     'pluginType': 'survey-text-custom',
#     'graphFilename': 'ggr_g1.png',
#     'VLAT_base': 'custom_answer',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/ggr_g1.png'}],
#   [{'gcbID': 'item_10',
#     'chart_cat': 'bar_chart_level_3',
#     'origStudy': 'GGR',
#     'blockNum': 10,
#     'origStudy_order_num': 'q_10',
#     'prompt': 'Compared to the placebo, which treatment leads to a larger decrease in the percentage of patients who die?',
#     'options': ['Crosicol', 'Hertinol', 'They are equal', "Can't say"],
#     'corrAns': 'They are equal',
#     'graphType': 'bar_chart',
#     'origStudy_taskCategorization': 'level_3',
#     'promptTitle': 'In a magazine you see two advertisements, one on page 5 and another on page 12.',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'ggr_g5.png',
#     'VLAT_base': 'custom_answer',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/ggr_g5.png'}],
#   [{'gcbID': 'item_11',
#     'chart_cat': 'line_chart_level_3',
#     'origStudy': 'GGR',
#     'blockNum': 11,
#     'origStudy_order_num': 'q_11',
#     'prompt': 'Which of the treatments contributes to a larger decrease in the percentage of sick patients?',
#     'options': ['Apsoriatin', 'Nopsorian', 'They are equal', "Can't say"],
#     'corrAns': "Can't say",
#     'graphType': 'line_chart',
#     'origStudy_taskCategorization': 'level_3',
#     'promptTitle': 'In the newspaper you see two advertisements, one on page 15 and another on page 17. Each is for a different treatment of psoriasis, and each includes a graph showing the effectiveness of the treatment over time.',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'ggr_g6.png',
#     'VLAT_base': 'custom_answer',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/ggr_g6.png'}],
#   [{'gcbID': 'item_12',
#     'chart_cat': 'line_chart_level_3',
#     'origStudy': 'GGR',
#     'blockNum': 12,
#     'origStudy_order_num': 'q_12',
#     'prompt': 'Between 1980 and 1990, which disease had a higher increase in the percentage of people affected?',
#     'options': ['Coliosis', 'Tiosis', 'The increase was equal', 'Cant say'],
#     'corrAns': 'Tiosis',
#     'graphType': 'line_chart',
#     'origStudy_taskCategorization': 'level_3',
#     'promptTitle': 'Here is some information about the imaginary disease Coliosis and Tiosis',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'ggr_g7.png',
#     'VLAT_base': 'custom_answer',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/ggr_g7.png'}],
#   [{'gcbID': 'item_13',
#     'chart_cat': 'bar_chart_level_3',
#     'origStudy': 'GGR',
#     'blockNum': 13,
#     'origStudy_order_num': 'q_13',
#     'prompt': 'What is the percentage of cancer patients who die after chemotherapy?',
#     'options': ['write your answer'],
#     'corrAns': '“50%” , “50”',
#     'graphType': 'bar_chart',
#     'origStudy_taskCategorization': 'level_3',
#     'promptTitle': 'Here is some information about cancer therapies',
#     'questionType': 'fill_in_blank',
#     'pluginType': 'survey-text-custom',
#     'graphFilename': 'ggr_g8.png',
#     'VLAT_base': 'custom_answer',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/ggr_g8.png'}],
#   [{'gcbID': 'item_14',
#     'chart_cat': 'line_chart_retrieve_value',
#     'origStudy': 'VLAT',
#     'blockNum': 14,
#     'origStudy_order_num': 'q_01',
#     'prompt': 'What was the price of a barrel of oil in February 2015?',
#     'options': ['$57.36', '$47.82', '$50.24', '$39.72', 'Skip'],
#     'corrAns': '$50.24',
#     'graphType': 'line_chart',
#     'origStudy_taskCategorization': 'retrieve_value',
#     'promptTitle': 'Monthly Oil Price History in 2015',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g1.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g1.png'}],
#   [{'gcbID': 'item_15',
#     'chart_cat': 'line_chart_find_extremum',
#     'origStudy': 'VLAT',
#     'blockNum': 14,
#     'origStudy_order_num': 'q_02',
#     'prompt': 'In which month was the price of a barrel of oil the lowest in 2015?',
#     'options': ['March', 'May', 'July', 'December', 'Skip'],
#     'corrAns': 'December',
#     'graphType': 'line_chart',
#     'origStudy_taskCategorization': 'find_extremum',
#     'promptTitle': 'Monthly Oil Price History in 2015',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g1.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g1.png'}],
#   [{'gcbID': 'item_16',
#     'chart_cat': 'line_chart_determine_Range',
#     'origStudy': 'VLAT',
#     'blockNum': 14,
#     'origStudy_order_num': 'q_03',
#     'prompt': 'What was the price range of a barrel of oil in 2015?',
#     'options': ['$35 - $65',
#      '$48.36 - $60.95',
#      '$37.04 - $48.36',
#      '$37.04 - $60.95',
#      'Skip'],
#     'corrAns': '$37.04 - $60.95',
#     'graphType': 'line_chart',
#     'origStudy_taskCategorization': 'determine_Range',
#     'promptTitle': 'Monthly Oil Price History in 2015',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g1.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g1.png'}],
#   [{'gcbID': 'item_17',
#     'chart_cat': 'line_chart_find_correlations_trends',
#     'origStudy': 'VLAT',
#     'blockNum': 14,
#     'origStudy_order_num': 'q_04',
#     'prompt': 'Over the course of the second half of 2015, the price of a barrel of oil was ____________.',
#     'options': ['rising', 'falling', 'staying', 'Skip'],
#     'corrAns': 'falling',
#     'graphType': 'line_chart',
#     'origStudy_taskCategorization': 'find_correlations_trends',
#     'promptTitle': 'Monthly Oil Price History in 2015',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g1.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g1.png'}],
#   [{'gcbID': 'item_18',
#     'chart_cat': 'line_chart_make_comparisons',
#     'origStudy': 'VLAT',
#     'blockNum': 14,
#     'origStudy_order_num': 'q_05',
#     'prompt': 'About how much did the price of a barrel of oil fall from April to September in 2015?',
#     'options': ['$5', '$15', '$17', '$45', 'Skip'],
#     'corrAns': '$15',
#     'graphType': 'line_chart',
#     'origStudy_taskCategorization': 'make_comparisons',
#     'promptTitle': 'Monthly Oil Price History in 2015',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g1.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g1.png'}],
#   [{'gcbID': 'item_19',
#     'chart_cat': 'bar_chart_retrieve_value',
#     'origStudy': 'VLAT',
#     'blockNum': 15,
#     'origStudy_order_num': 'q_06',
#     'prompt': 'What is the average internet speed in Japan?',
#     'options': ['10 Mbps', '14 Mbps', '15 Mbps', '16 Mbps', 'Skip'],
#     'corrAns': '15 Mbps',
#     'graphType': 'bar_chart',
#     'origStudy_taskCategorization': 'retrieve_value',
#     'promptTitle': 'Average Internet Speeds in Asia',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g2.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g2.png'}],
#   [{'gcbID': 'item_2',
#     'chart_cat': 'bar_chart_level_2',
#     'origStudy': 'GGR',
#     'blockNum': 2,
#     'origStudy_order_num': 'q_02',
#     'prompt': "What is the difference between the percentage of patients who recovered after a surgery and the percetage of patients who recovered after radiation therapy?'",
#     'options': ['write your answer'],
#     'corrAns': '15, 15%',
#     'graphType': 'bar_chart',
#     'origStudy_taskCategorization': 'level_2',
#     'promptTitle': 'Here is some information about cancer therapies',
#     'questionType': 'fill_in_blank',
#     'pluginType': 'survey-text-custom',
#     'graphFilename': 'ggr_g1.png',
#     'VLAT_base': 'custom_answer',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/ggr_g1.png'}],
#   [{'gcbID': 'item_20',
#     'chart_cat': 'bar_chart_find_extremum',
#     'origStudy': 'VLAT',
#     'blockNum': 15,
#     'origStudy_order_num': 'q_07',
#     'prompt': 'In which country is the average internet speed the fastest in Asia?',
#     'options': ['China', 'Hong Kong', 'South Korea', 'Vietnam', 'Skip'],
#     'corrAns': 'South Korea',
#     'graphType': 'bar_chart',
#     'origStudy_taskCategorization': 'find_extremum',
#     'promptTitle': 'Average Internet Speeds in Asia',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g2.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g2.png'}],
#   [{'gcbID': 'item_21',
#     'chart_cat': 'bar_chart_determine_Range',
#     'origStudy': 'VLAT',
#     'blockNum': 15,
#     'origStudy_order_num': 'q_08',
#     'prompt': 'What is the range of the average internet speed in Asia?',
#     'options': ['0 - 22 Mbps',
#      '2 - 20.5 Mbps',
#      '3 - 20 Mbps',
#      '3.4 - 7.8 Mbps',
#      'Skip'],
#     'corrAns': '2 - 20.5 Mbps',
#     'graphType': 'bar_chart',
#     'origStudy_taskCategorization': 'determine_Range',
#     'promptTitle': 'Average Internet Speeds in Asia',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g2.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g2.png'}],
#   [{'gcbID': 'item_22',
#     'chart_cat': 'bar_chart_make_comparisons',
#     'origStudy': 'VLAT',
#     'blockNum': 15,
#     'origStudy_order_num': 'q_09',
#     'prompt': 'How many countries in Asia is the average internet speed slower than Thailand?',
#     'options': ['5 countries',
#      '6 countries',
#      '7 countries',
#      '8 countries',
#      'Skip'],
#     'corrAns': '7 countries',
#     'graphType': 'bar_chart',
#     'origStudy_taskCategorization': 'make_comparisons',
#     'promptTitle': 'Average Internet Speeds in Asia',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g2.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g2.png'}],
#   [{'gcbID': 'item_23',
#     'chart_cat': 'stacked_bart_chart_retrieve_value',
#     'origStudy': 'VLAT',
#     'blockNum': 16,
#     'origStudy_order_num': 'q_10',
#     'prompt': 'What is the cost of peanuts in Las Vegas?',
#     'options': ['$12', '$16.7', '$23.4', '$35.4', 'Skip'],
#     'corrAns': '$12',
#     'graphType': 'stacked_bart_chart',
#     'origStudy_taskCategorization': 'retrieve_value',
#     'promptTitle': 'Hotel Costs of Room Service',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g3.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g3.png'}],
#   [{'gcbID': 'item_24',
#     'chart_cat': 'stacked_bart_chart_retrieve_value',
#     'origStudy': 'VLAT',
#     'blockNum': 16,
#     'origStudy_order_num': 'q_11',
#     'prompt': 'About what is the ratio of the cost of a sandwich to the total cost of room service in Seattle?',
#     'options': ['1 to 10', '2 to 10', '4 to 10', '6 to 10', 'Skip'],
#     'corrAns': '4 to 10',
#     'graphType': 'stacked_bart_chart',
#     'origStudy_taskCategorization': 'retrieve_value',
#     'promptTitle': 'Hotel Costs of Room Service',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g3.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g3.png'}],
#   [{'gcbID': 'item_25',
#     'chart_cat': 'stacked_bart_chart_find_extremum',
#     'origStudy': 'VLAT',
#     'blockNum': 16,
#     'origStudy_order_num': 'q_12',
#     'prompt': 'In which city is the cost of soda the highest?',
#     'options': ['New York City',
#      'Las Vegas',
#      'Atlanta',
#      'Washington D.C.',
#      'Skip'],
#     'corrAns': 'Washington D.C.',
#     'graphType': 'stacked_bart_chart',
#     'origStudy_taskCategorization': 'find_extremum',
#     'promptTitle': 'Hotel Costs of Room Service',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g3.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g3.png'}],
#   [{'gcbID': 'item_27',
#     'chart_cat': 'stacked_bart_chart_make_comparisons',
#     'origStudy': 'VLAT',
#     'blockNum': 16,
#     'origStudy_order_num': 'q_14',
#     'prompt': 'The cost of vodka in Atlanta is higher than that of Honolulu.',
#     'options': ['True', 'False', 'Skip'],
#     'corrAns': 'True',
#     'graphType': 'stacked_bart_chart',
#     'origStudy_taskCategorization': 'make_comparisons',
#     'promptTitle': 'Hotel Costs of Room Service',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g3.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g3.png'}],
#   [{'gcbID': 'item_28',
#     'chart_cat': 'stacked_bart_chart_make_comparisons',
#     'origStudy': 'VLAT',
#     'blockNum': 16,
#     'origStudy_order_num': 'q_15',
#     'prompt': 'The ratio of the cost of Soda to the cost of Water in Orlando is higher than that of Washington D.C.',
#     'options': ['True', 'False', 'Skip'],
#     'corrAns': 'False',
#     'graphType': 'stacked_bart_chart',
#     'origStudy_taskCategorization': 'make_comparisons',
#     'promptTitle': 'Hotel Costs of Room Service',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g3.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g3.png'}],
#   [{'gcbID': 'item_29',
#     'chart_cat': 'normalized_stacked_bar_chart_retrieve_value',
#     'origStudy': 'VLAT',
#     'blockNum': 17,
#     'origStudy_order_num': 'q_16',
#     'prompt': 'What is the approval rating of Republicans among the people who have the education level of Postgraduate Study?',
#     'options': ['38%', '47%', '53%', '62%', 'Skip'],
#     'corrAns': '38%',
#     'graphType': 'normalized_stacked_bar_chart',
#     'origStudy_taskCategorization': 'retrieve_value',
#     'promptTitle': 'Election Exit Poll of California State by Education',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g4.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g4.png'}],
#   [{'gcbID': 'item_3',
#     'chart_cat': 'pie_chart_level_1',
#     'origStudy': 'GGR',
#     'blockNum': 3,
#     'origStudy_order_num': 'q_03',
#     'prompt': 'Of all the people who die from cancer, approximately what percentage dies from lung cancer?',
#     'options': ['write your answer'],
#     'corrAns': '25%, 25',
#     'graphType': 'pie_chart',
#     'origStudy_taskCategorization': 'level_1',
#     'promptTitle': 'Here is some information about different forms of cancer',
#     'questionType': 'fill_in_blank',
#     'pluginType': 'survey-text-custom',
#     'graphFilename': 'ggr_g2.png',
#     'VLAT_base': 'custom_answer',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/ggr_g2.png'}],
#   [{'gcbID': 'item_30',
#     'chart_cat': 'normalized_stacked_bar_chart_find_extremum',
#     'origStudy': 'VLAT',
#     'blockNum': 17,
#     'origStudy_order_num': 'q_17',
#     'prompt': 'What is the education level of people in which the Democrats have the lowest approval rating?',
#     'options': ['High School Graduate or Less',
#      'Some College Degree',
#      'College Graduate',
#      'Postgraduate study',
#      'Skip'],
#     'corrAns': 'College Graduate',
#     'graphType': 'normalized_stacked_bar_chart',
#     'origStudy_taskCategorization': 'find_extremum',
#     'promptTitle': 'Election Exit Poll of California State by Education',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g4.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g4.png'}],
#   [{'gcbID': 'item_31',
#     'chart_cat': 'normalized_stacked_bar_chart_make_comparisons',
#     'origStudy': 'VLAT',
#     'blockNum': 17,
#     'origStudy_order_num': 'q_18',
#     'prompt': 'The approval rating of Republicans for the people who have the education level of Some College Degree is lower than that for the people who have the education level of Postgraduate Study.',
#     'options': ['True', 'False', 'Skip'],
#     'corrAns': 'False',
#     'graphType': 'normalized_stacked_bar_chart',
#     'origStudy_taskCategorization': 'make_comparisons',
#     'promptTitle': 'Election Exit Poll of California State by Education',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g4.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g4.png'}],
#   [{'gcbID': 'item_32',
#     'chart_cat': 'pie_chart_retrieve_value',
#     'origStudy': 'VLAT',
#     'blockNum': 18,
#     'origStudy_order_num': 'q_19',
#     'prompt': 'About what is the global smartphone market share of Samsung?',
#     'options': ['15%', '25%', '33%', '50%', 'Skip'],
#     'corrAns': '25%',
#     'graphType': 'pie_chart',
#     'origStudy_taskCategorization': 'retrieve_value',
#     'promptTitle': 'Global Smartphone Market Share (%)',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g5.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g5.png'}],
#   [{'gcbID': 'item_33',
#     'chart_cat': 'pie_chart_find_extremum',
#     'origStudy': 'VLAT',
#     'blockNum': 18,
#     'origStudy_order_num': 'q_20',
#     'prompt': 'In which company is the global smartphone market share the smallest?',
#     'options': ['Apple', 'Xiaomi', 'Lenovo', 'Others', 'Skip'],
#     'corrAns': 'Lenovo',
#     'graphType': 'pie_chart',
#     'origStudy_taskCategorization': 'find_extremum',
#     'promptTitle': 'Global Smartphone Market Share (%)',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g5.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g5.png'}],
#   [{'gcbID': 'item_34',
#     'chart_cat': 'pie_chart_make_comparisons',
#     'origStudy': 'VLAT',
#     'blockNum': 18,
#     'origStudy_order_num': 'q_21',
#     'prompt': 'The global smartphone market share of Apple is larger than that of Huawei.',
#     'options': ['True', 'False', 'Skip'],
#     'corrAns': 'True',
#     'graphType': 'pie_chart',
#     'origStudy_taskCategorization': 'make_comparisons',
#     'promptTitle': 'Global Smartphone Market Share (%)',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g5.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g5.png'}],
#   [{'gcbID': 'item_35',
#     'chart_cat': 'histogram_retrieve_value',
#     'origStudy': 'VLAT',
#     'blockNum': 19,
#     'origStudy_order_num': 'q_22',
#     'prompt': 'How many people have rated the taxi between 4.0 and 4.2?',
#     'options': ['145', '153', '200', '240', 'Skip'],
#     'corrAns': '153',
#     'graphType': 'histogram',
#     'origStudy_taskCategorization': 'retrieve_value',
#     'promptTitle': 'Taxi Passenger Ratings',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g6.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g6.png'}],
#   [{'gcbID': 'item_36',
#     'chart_cat': 'histogram_find_extremum',
#     'origStudy': 'VLAT',
#     'blockNum': 19,
#     'origStudy_order_num': 'q_23',
#     'prompt': 'What is the rating that the people have rated the taxi the most?',
#     'options': ['4.2 - 4.4', '4.4 - 4.6', '4.6 - 4.8', '4.8 - 5.0', 'Skip'],
#     'corrAns': '4.4 - 4.6',
#     'graphType': 'histogram',
#     'origStudy_taskCategorization': 'find_extremum',
#     'promptTitle': 'Taxi Passenger Ratings',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g6.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g6.png'}],
#   [{'gcbID': 'item_38',
#     'chart_cat': 'histogram_characterize_distribution',
#     'origStudy': 'VLAT',
#     'blockNum': 19,
#     'origStudy_order_num': 'q_25',
#     'prompt': 'More people have rated the taxi between 4.6 and 4.8 than between 4.2 and 4.4.',
#     'options': ['True', 'False', 'Skip'],
#     'corrAns': 'True',
#     'graphType': 'histogram',
#     'origStudy_taskCategorization': 'characterize_distribution',
#     'promptTitle': 'Taxi Passenger Ratings',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g6.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g6.png'}],
#   [{'gcbID': 'item_39',
#     'chart_cat': 'scatterplot_retrieve_value',
#     'origStudy': 'VLAT',
#     'blockNum': 20,
#     'origStudy_order_num': 'q_25',
#     'prompt': 'What is the weight for the person who is 165.1 cm tall?',
#     'options': ['53.9 kg', '67.7 kg', '70.5 kg', '82.7 kg', 'Skip'],
#     'corrAns': '“70.5 kg',
#     'graphType': 'scatterplot',
#     'origStudy_taskCategorization': 'retrieve_value',
#     'promptTitle': 'Height vs. Weight of 85 Males',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g7.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g7.png'}],
#   [{'gcbID': 'item_4',
#     'chart_cat': 'pie_chart_level_2',
#     'origStudy': 'GGR',
#     'blockNum': 4,
#     'origStudy_order_num': 'q_04',
#     'prompt': 'Approximately what percentage of people who die from cancer die from colon cancer, breast cancer, and prostate cancer taken together?',
#     'options': ['write your answer'],
#     'corrAns': '25%, 25',
#     'graphType': 'pie_chart',
#     'origStudy_taskCategorization': 'level_2',
#     'promptTitle': 'Here is some information about different forms of cancer',
#     'questionType': 'fill_in_blank',
#     'pluginType': 'survey-text-custom',
#     'graphFilename': 'ggr_g2.png',
#     'VLAT_base': 'custom_answer',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/ggr_g2.png'}],
#   [{'gcbID': 'item_40',
#     'chart_cat': 'scatterplot_find_extremum',
#     'origStudy': 'VLAT',
#     'blockNum': 20,
#     'origStudy_order_num': 'q_26',
#     'prompt': 'What is the height for the tallest person among the 85 males?',
#     'options': ['175.3 cm', '192 cm', '197.1 cm', '200 cm', 'Skip'],
#     'corrAns': '“197.1 cm”',
#     'graphType': 'scatterplot',
#     'origStudy_taskCategorization': 'find_extremum',
#     'promptTitle': 'Height vs. Weight of 85 Males',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g7.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g7.png'}],
#   [{'gcbID': 'item_41',
#     'chart_cat': 'scatterplot_determine_Range',
#     'origStudy': 'VLAT',
#     'blockNum': 20,
#     'origStudy_order_num': 'q_27',
#     'prompt': 'What is the range in weight for the 85 males?',
#     'options': ['40 - 130 kg',
#      '62.3 - 90.9 kg',
#      '53.9 - 102.3 kg',
#      '53.9 - 123.6 kg',
#      'Skip'],
#     'corrAns': '53.9 - 102.3 kg',
#     'graphType': 'scatterplot',
#     'origStudy_taskCategorization': 'determine_Range',
#     'promptTitle': 'Height vs. Weight of 85 Males',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g7.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g7.png'}],
#   [{'gcbID': 'item_43',
#     'chart_cat': 'scatterplot_find_anomolies',
#     'origStudy': 'VLAT',
#     'blockNum': 20,
#     'origStudy_order_num': 'q_29',
#     'prompt': 'What is the height for a person who lies outside the others the most?',
#     'options': ['175.3 cm', '192 cm', '197.1 cm', '200 cm', 'Skip'],
#     'corrAns': '“175.3 cm”',
#     'graphType': 'scatterplot',
#     'origStudy_taskCategorization': 'find_anomolies',
#     'promptTitle': 'Height vs. Weight of 85 Males',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g7.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g7.png'}],
#   [{'gcbID': 'item_44',
#     'chart_cat': 'scatterplot_find_clusters',
#     'origStudy': 'VLAT',
#     'blockNum': 20,
#     'origStudy_order_num': 'q_30',
#     'prompt': 'A group of males are gathered around the height of 176 cm and the weight of 70 kg.',
#     'options': ['True', 'False', 'Skip'],
#     'corrAns': 'True',
#     'graphType': 'scatterplot',
#     'origStudy_taskCategorization': 'find_clusters',
#     'promptTitle': 'Height vs. Weight of 85 Males',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g7.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g7.png'}],
#   [{'gcbID': 'item_45',
#     'chart_cat': 'scatterplot_find_correlations_trends',
#     'origStudy': 'VLAT',
#     'blockNum': 20,
#     'origStudy_order_num': 'q_31',
#     'prompt': 'There is a negative linear relationship between the height and the weight of the 85 males.',
#     'options': ['True', 'False', 'Skip'],
#     'corrAns': 'False',
#     'graphType': 'scatterplot',
#     'origStudy_taskCategorization': 'find_correlations_trends',
#     'promptTitle': 'Height vs. Weight of 85 Males',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g7.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g7.png'}],
#   [{'gcbID': 'item_46',
#     'chart_cat': 'scatterplot_make_comparisons',
#     'origStudy': 'VLAT',
#     'blockNum': 20,
#     'origStudy_order_num': 'q_32',
#     'prompt': 'The weights for males with the height of 188 cm are all the same.',
#     'options': ['True', 'False', 'Skip'],
#     'corrAns': 'False',
#     'graphType': 'scatterplot',
#     'origStudy_taskCategorization': 'make_comparisons',
#     'promptTitle': 'Height vs. Weight of 85 Males',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g7.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g7.png'}],
#   [{'gcbID': 'item_47',
#     'chart_cat': 'area_chart_retrieve_value',
#     'origStudy': 'VLAT',
#     'blockNum': 21,
#     'origStudy_order_num': 'q_33',
#     'prompt': 'What was the average price of a pound of coffee beans in September 2013?',
#     'options': ['$4.9', '$5.0', '$5.1', '$5.2', 'Skip'],
#     'corrAns': '$5.1',
#     'graphType': 'area_chart',
#     'origStudy_taskCategorization': 'retrieve_value',
#     'promptTitle': 'Average Coffee Bean Price from 2013 to 2014',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g8.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g8.png'}],
#   [{'gcbID': 'item_48',
#     'chart_cat': 'area_chart_find_extremum',
#     'origStudy': 'VLAT',
#     'blockNum': 21,
#     'origStudy_order_num': 'q_34',
#     'prompt': 'When was the average price of a pound of coffee beans at minimum?',
#     'options': ['April 2013',
#      'September 2013',
#      'June 2014',
#      'December 2014',
#      'Skip'],
#     'corrAns': 'December 2014',
#     'graphType': 'area_chart',
#     'origStudy_taskCategorization': 'find_extremum',
#     'promptTitle': 'Average Coffee Bean Price from 2013 to 2014',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g8.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g8.png'}],
#   [{'gcbID': 'item_49',
#     'chart_cat': 'area_chart_determine_Range',
#     'origStudy': 'VLAT',
#     'blockNum': 21,
#     'origStudy_order_num': 'q_35',
#     'prompt': 'What was the range of the average price of a pound of coffee beans between January 2013 and December 2014?',
#     'options': ['$4.4 - $6.2',
#      '$4.6 - $5.9',
#      '$4.6 - $6.0',
#      '$4.6 - $6.1',
#      'Skip'],
#     'corrAns': '$4.6 - $6.0',
#     'graphType': 'area_chart',
#     'origStudy_taskCategorization': 'determine_Range',
#     'promptTitle': 'Average Coffee Bean Price from 2013 to 2014',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g8.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g8.png'}],
#   [{'gcbID': 'item_5',
#     'chart_cat': 'line_chart_level_1',
#     'origStudy': 'GGR',
#     'blockNum': 5,
#     'origStudy_order_num': 'q_05',
#     'prompt': 'Approximately what percentage of people had Adeolitis in the year 2000',
#     'options': ['write your answer'],
#     'corrAns': '20%, 20',
#     'graphType': 'line_chart',
#     'origStudy_taskCategorization': 'level_1',
#     'promptTitle': 'Here is some information about an imaginary disease called Adeolitis.',
#     'questionType': 'fill_in_blank',
#     'pluginType': 'survey-text-custom',
#     'graphFilename': 'ggr_g3.png',
#     'VLAT_base': 'custom_answer',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/ggr_g3.png'}],
#   [{'gcbID': 'item_50',
#     'chart_cat': 'area_chart_find_correlations_trends',
#     'origStudy': 'VLAT',
#     'blockNum': 21,
#     'origStudy_order_num': 'q_36',
#     'prompt': 'Over the course of 2013, the average price of a pound of coffee beans was ____________.',
#     'options': ['rising', 'falling', 'staying', 'Skip'],
#     'corrAns': 'falling',
#     'graphType': 'area_chart',
#     'origStudy_taskCategorization': 'find_correlations_trends',
#     'promptTitle': 'Average Coffee Bean Price from 2013 to 2014',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g8.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g8.png'}],
#   [{'gcbID': 'item_52',
#     'chart_cat': 'stacked_area_chart_retrieve_value',
#     'origStudy': 'VLAT',
#     'blockNum': 22,
#     'origStudy_order_num': 'q_38',
#     'prompt': 'What was the number of girls named ‘Amelia’ in 2010 in the UK?',
#     'options': ['1500', '3800', '4200', '8000', 'Skip'],
#     'corrAns': '4200',
#     'graphType': 'stacked_area_chart',
#     'origStudy_taskCategorization': 'retrieve_value',
#     'promptTitle': "Popular Girls' Names in the UK",
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g9.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g9.png'}],
#   [{'gcbID': 'item_53',
#     'chart_cat': 'stacked_area_chart_retrieve_value',
#     'origStudy': 'VLAT',
#     'blockNum': 22,
#     'origStudy_order_num': 'q_39',
#     'prompt': 'About what was the ratio of the number of girls named ‘Olivia’ to those named ‘Isla’ in 2014 in the UK?',
#     'options': ['1 to 1', '1 to 2', '1 to 3', '1 to 4', 'Skip'],
#     'corrAns': '1 to 1',
#     'graphType': 'stacked_area_chart',
#     'origStudy_taskCategorization': 'retrieve_value',
#     'promptTitle': "Popular Girls' Names in the UK",
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g9.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g9.png'}],
#   [{'gcbID': 'item_54',
#     'chart_cat': 'stacked_area_chart_find_extremum',
#     'origStudy': 'VLAT',
#     'blockNum': 22,
#     'origStudy_order_num': 'q_40',
#     'prompt': 'Over the course of years between 2009 and 2014, when was the number of girls named ‘Amelia’ at the maximum?',
#     'options': ['2009', '2011', '2012', '2014', 'Skip'],
#     'corrAns': '2012',
#     'graphType': 'stacked_area_chart',
#     'origStudy_taskCategorization': 'find_extremum',
#     'promptTitle': "Popular Girls' Names in the UK",
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g9.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g9.png'}],
#   [{'gcbID': 'item_56',
#     'chart_cat': 'stacked_area_chart_find_correlations_trends',
#     'origStudy': 'VLAT',
#     'blockNum': 22,
#     'origStudy_order_num': 'q_42',
#     'prompt': 'The number of girls named ‘Isla’ was __________ from 2009 to 2012.',
#     'options': ['rising', 'falling', 'staying', 'Skip'],
#     'corrAns': 'rising',
#     'graphType': 'stacked_area_chart',
#     'origStudy_taskCategorization': 'find_correlations_trends',
#     'promptTitle': "Popular Girls' Names in the UK",
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g9.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g9.png'}],
#   [{'gcbID': 'item_57',
#     'chart_cat': 'stacked_area_chart_make_comparisons',
#     'origStudy': 'VLAT',
#     'blockNum': 22,
#     'origStudy_order_num': 'q_43',
#     'prompt': 'In the UK, the number of girls named ‘Amelia’ in 2014 was more than it was in 2013.',
#     'options': ['True', 'False', 'Skip'],
#     'corrAns': 'False',
#     'graphType': 'stacked_area_chart',
#     'origStudy_taskCategorization': 'make_comparisons',
#     'promptTitle': "Popular Girls' Names in the UK",
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g9.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g9.png'}],
#   [{'gcbID': 'item_58',
#     'chart_cat': 'stacked_area_chart_make_comparisons',
#     'origStudy': 'VLAT',
#     'blockNum': 22,
#     'origStudy_order_num': 'q_44',
#     'prompt': 'Over the course of years between 2009 and 2014, the number of girls named ‘Isla’ was always more than ‘Olivia’.',
#     'options': ['True', 'False', 'Skip'],
#     'corrAns': 'False',
#     'graphType': 'stacked_area_chart',
#     'origStudy_taskCategorization': 'make_comparisons',
#     'promptTitle': "Popular Girls' Names in the UK",
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g9.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g9.png'}],
#   [{'gcbID': 'item_59',
#     'chart_cat': 'bubble_chart_retrieve_value',
#     'origStudy': 'VLAT',
#     'blockNum': 23,
#     'origStudy_order_num': 'q_45',
#     'prompt': 'What is the total length of the metro system in Beijing?',
#     'options': ['330 km', '400 km', '530 km', '560 km', 'Skip'],
#     'corrAns': '530 km',
#     'graphType': 'bubble_chart',
#     'origStudy_taskCategorization': 'retrieve_value',
#     'promptTitle': 'Metro Systems of the World',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g10.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g10.png'}],
#   [{'gcbID': 'item_6',
#     'chart_cat': 'line_chart_level_2',
#     'origStudy': 'GGR',
#     'blockNum': 6,
#     'origStudy_order_num': 'q_06',
#     'prompt': 'When was the increase in the percentage of people with Adeolitis higher?',
#     'options': ['From 1975 to 1980',
#      'From 2000 to 2005',
#      'Increase was the same in both intervals',
#      "Don't know"],
#     'corrAns': 'Increase was the same in both intervals',
#     'graphType': 'line_chart',
#     'origStudy_taskCategorization': 'level_2',
#     'promptTitle': 'Here is some information about an imaginary disease called Adeolitis.',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'ggr_g3.png',
#     'VLAT_base': 'custom_answer',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/ggr_g3.png'}],
#   [{'gcbID': 'item_60',
#     'chart_cat': 'bubble_chart_find_extremum',
#     'origStudy': 'VLAT',
#     'blockNum': 23,
#     'origStudy_order_num': 'q_46',
#     'prompt': 'Which city’s metro system has the largest number of stations?',
#     'options': ['Seoul', 'Beijing', 'New York City', 'Shanghai', 'Skip'],
#     'corrAns': 'New York City',
#     'graphType': 'bubble_chart',
#     'origStudy_taskCategorization': 'find_extremum',
#     'promptTitle': 'Metro Systems of the World',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g10.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g10.png'}],
#   [{'gcbID': 'item_61',
#     'chart_cat': 'bubble chart_determine_Range',
#     'origStudy': 'VLAT',
#     'blockNum': 23,
#     'origStudy_order_num': 'q_47',
#     'prompt': 'What is the range of the total length of the metro systems?',
#     'options': ['150 - 600 km',
#      '240 - 380 km',
#      '240 - 560 km',
#      '180 - 560 km',
#      'Skip'],
#     'corrAns': '180 - 560 km',
#     'graphType': 'bubble chart',
#     'origStudy_taskCategorization': 'determine_Range',
#     'promptTitle': 'Metro Systems of the World',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g10.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g10.png'}],
#   [{'gcbID': 'item_63',
#     'chart_cat': 'bubble_chart_find_anomolies',
#     'origStudy': 'VLAT',
#     'blockNum': 23,
#     'origStudy_order_num': 'q_49',
#     'prompt': 'Which city’s metro system does lie outside the relationship between the total system length and the number of stations most?',
#     'options': ['Tokyo', 'New York City', 'Beijing', 'London', 'Skip'],
#     'corrAns': 'New York City',
#     'graphType': 'bubble_chart',
#     'origStudy_taskCategorization': 'find_anomolies',
#     'promptTitle': 'Metro Systems of the World',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g10.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g10.png'}],
#   [{'gcbID': 'item_64',
#     'chart_cat': 'bubble_chart_find_clusters',
#     'origStudy': 'VLAT',
#     'blockNum': 23,
#     'origStudy_order_num': 'q_50',
#     'prompt': 'A group of the metro systems of the world has approximately 300 stations and around a 200km system length.',
#     'options': ['True', 'False', 'Skip'],
#     'corrAns': 'False',
#     'graphType': 'bubble_chart',
#     'origStudy_taskCategorization': 'find_clusters',
#     'promptTitle': 'Metro Systems of the World',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g10.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g10.png'}],
#   [{'gcbID': 'item_65',
#     'chart_cat': 'bubble_chart_find_correlations_trends',
#     'origStudy': 'VLAT',
#     'blockNum': 23,
#     'origStudy_order_num': 'q_51',
#     'prompt': 'In general, the ridership of the metro system increases as the number of stations increases.',
#     'options': ['True', 'False', 'Skip'],
#     'corrAns': 'False',
#     'graphType': 'bubble_chart',
#     'origStudy_taskCategorization': 'find_correlations_trends',
#     'promptTitle': 'Metro Systems of the World',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g10.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g10.png'}],
#   [{'gcbID': 'item_66',
#     'chart_cat': 'bubble_chart_make_comparisons',
#     'origStudy': 'VLAT',
#     'blockNum': 23,
#     'origStudy_order_num': 'q_52',
#     'prompt': 'The metro system in Shanghai has more ridership than the metro system in Beijing.',
#     'options': ['True', 'False', 'Skip'],
#     'corrAns': 'False',
#     'graphType': 'bubble_chart',
#     'origStudy_taskCategorization': 'make_comparisons',
#     'promptTitle': 'Metro Systems of the World',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g10.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g10.png'}],
#   [{'gcbID': 'item_67',
#     'chart_cat': 'choropleth_retrieve_value',
#     'origStudy': 'VLAT',
#     'blockNum': 24,
#     'origStudy_order_num': 'q_53',
#     'prompt': 'What was the unemployment rate for Indiana (IN) in 2015?',
#     'options': ['1.1% - 2.3%',
#      '2.3% - 3.4%',
#      '3.4% - 4.6%',
#      '4.0% - 5.0%',
#      'Skip'],
#     'corrAns': '4.0% - 5.0%',
#     'graphType': 'choropleth',
#     'origStudy_taskCategorization': 'retrieve_value',
#     'promptTitle': 'Unemployment Rates for States in 2015',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g11.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g11.png'}],
#   [{'gcbID': 'item_68',
#     'chart_cat': 'choropleth_find_extremum',
#     'origStudy': 'VLAT',
#     'blockNum': 24,
#     'origStudy_order_num': 'q_54',
#     'prompt': 'In which state was the unemployment rate the highest in 2015?',
#     'options': ['Alaska (AK)',
#      'New Mexico (NM)',
#      'Florida (FL)',
#      'New York (NY)',
#      'Skip'],
#     'corrAns': 'New Mexico (NM)',
#     'graphType': 'choropleth',
#     'origStudy_taskCategorization': 'find_extremum',
#     'promptTitle': 'Unemployment Rates for States in 2015',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g11.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g11.png'}],
#   [{'gcbID': 'item_69',
#     'chart_cat': 'choropleth_make_comparisons',
#     'origStudy': 'VLAT',
#     'blockNum': 24,
#     'origStudy_order_num': 'q_55',
#     'prompt': 'In 2015, the unemployment rate for Washington (WA) was higher than that of Wisconsin (WI).',
#     'options': ['True', 'False', 'Skip'],
#     'corrAns': 'True',
#     'graphType': 'choropleth',
#     'origStudy_taskCategorization': 'make_comparisons',
#     'promptTitle': 'Unemployment Rates for States in 2015',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g11.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g11.png'}],
#   [{'gcbID': 'item_7',
#     'chart_cat': 'line_chart_level_3',
#     'origStudy': 'GGR',
#     'blockNum': 7,
#     'origStudy_order_num': 'q_07',
#     'prompt': 'According to your best guess, what will the percentage of people with Adeolitis be in the year 2010?',
#     'options': ['write your answer'],
#     'corrAns': '23, 24, 25',
#     'graphType': 'line_chart',
#     'origStudy_taskCategorization': 'level_3',
#     'promptTitle': 'Here is some information about an imaginary disease called Adeolitis',
#     'questionType': 'fill_in_blank',
#     'pluginType': 'survey-text-custom',
#     'graphFilename': 'ggr_g3.png',
#     'VLAT_base': 'custom_answer',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/ggr_g3.png'}],
#   [{'gcbID': 'item_71',
#     'chart_cat': 'treemap_find_extremum',
#     'origStudy': 'VLAT',
#     'blockNum': 25,
#     'origStudy_order_num': 'q_57',
#     'prompt': 'For which website was the number of unique visitors the largest in 2010?',
#     'options': ['Facebook', 'Amazon', 'Bing', 'Google', 'Skip'],
#     'corrAns': 'Google',
#     'graphType': 'treemap',
#     'origStudy_taskCategorization': 'find_extremum',
#     'promptTitle': 'The Number of Unique Visitors for Websites in 2010',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g12.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g12.png'}],
#   [{'gcbID': 'item_72',
#     'chart_cat': 'treemap_make_comparisons',
#     'origStudy': 'VLAT',
#     'blockNum': 25,
#     'origStudy_order_num': 'q_58',
#     'prompt': 'The number of unique visitors for Amazon was more than that of Yahoo in 2010.',
#     'options': ['True', 'False '],
#     'corrAns': '“False',
#     'graphType': 'treemap',
#     'origStudy_taskCategorization': 'make_comparisons',
#     'promptTitle': 'The Number of Unique Visitors for Websites in 2010',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g12.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g12.png'}],
#   [{'gcbID': 'item_73',
#     'chart_cat': 'treemap_find_correlations_trends',
#     'origStudy': 'VLAT',
#     'blockNum': 25,
#     'origStudy_order_num': 'q_59',
#     'prompt': 'Samsung is nested in the Financial category.',
#     'options': ['True', 'False', 'Skip'],
#     'corrAns': 'False',
#     'graphType': 'treemap',
#     'origStudy_taskCategorization': 'find_correlations_trends',
#     'promptTitle': 'The Number of Unique Visitors for Websites in 2010',
#     'questionType': 'multiple_choice',
#     'pluginType': 'survey-multi-choice-custom',
#     'graphFilename': 'vlat_g12.png',
#     'VLAT_base': '1',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/vlat_g12.png'}],
#   [{'gcbID': 'item_8',
#     'chart_cat': 'icon_array_level_1',
#     'origStudy': 'GGR',
#     'blockNum': 8,
#     'origStudy_order_num': 'q_08',
#     'prompt': 'Of 100 patients with disease X, how many are women',
#     'options': ['write your answer'],
#     'corrAns': '40',
#     'graphType': 'icon_array',
#     'origStudy_taskCategorization': 'level_1',
#     'promptTitle': 'The following figure shows the number of men and women among patients with disease X. The total number of circles is 100.',
#     'questionType': 'fill_in_blank',
#     'pluginType': 'survey-text-custom',
#     'graphFilename': 'ggr_g4.png',
#     'VLAT_base': 'custom_answer',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/ggr_g4.png'}],
#   [{'gcbID': 'item_9',
#     'chart_cat': 'icon_array_level_2',
#     'origStudy': 'GGR',
#     'blockNum': 9,
#     'origStudy_order_num': 'q_09',
#     'prompt': 'How many more men than women are there among 100 patients with disease X?',
#     'options': ['write your answer'],
#     'corrAns': '20',
#     'graphType': 'icon_array',
#     'origStudy_taskCategorization': 'level_2',
#     'promptTitle': 'The following figure shows the number of men and women among patients with disease X. The total number of circles is 100.',
#     'questionType': 'fill_in_blank',
#     'pluginType': 'survey-text-custom',
#     'graphFilename': 'ggr_g4.png',
#     'VLAT_base': 'custom_answer',
#     'experimentName': 'graph_comprehension_benchmarking',
#     'filename_navpath': '/Users/hl/ucsd/fyp/graph-comprehension-benchmarking/stimuli/images/ggr_g4.png'}]],
#  'games': []}

# %%
## check dir names in mongoDB
db.list_collection_names()
# Out:
# ['iternum2_recog2',
#  'lax_drawing_nuts-bolts_all',
#  'physics_explanations',
#  'physics_trust_agent',
#  'environment_structuring_tan_search_post',
#  'lax_drawing_wheels_all',
#  'human-physics-benchmarking-containment-pilot_example',
#  'human-physics-benchmarking-linking-pilot_example',
#  'human-physics-benchmarking-towers-pilot_example',
#  'kiddraw_annotations_small_animals',
#  'human-physics-benchmarking-clothiness-pilot_iteration_1',
#  'tools_for_block_construction_playground_action_and_subgoal_generation',
#  'human-physics-benchmarking-dominoes-redyellow-pilot_production_1',
#  'causaldraw_annotations_patching',
#  'causaldraw',
#  'lax_structures_castle_all',
#  'lax_structures_city',
#  'zipping_3_counterbalanced',
#  'curiotower_curiodrop',
#  'human-physics-benchmarking-collision_iteration_2',
#  'zipping_test',
#  'environment_structuring_tan_arrangement_select_all_rt_spread',
#  'graphical_conventions_semantic_mapping',
#  'kiddraw_annotations_vehicles',
#  'physics_trust_agent_study2_v2',
#  'human-physics-benchmarking-towers-pilot_production_2',
#  'causaldraw_annotations',
#  'lax_drawing_furniture_all',
#  'lax_reconstruction_stims_house',
#  'human-physics-benchmarking-collision-pilot_production_2',
#  'human-physics-benchmarking-towers-pilot_production_1',
#  'part_annotations_group3',
#  'collabdraw_collab8_recog',
#  'environment_structuring_tan_search',
#  'graphical_conventions_semantic_mapping_patching',
#  'part_annotations_group2',
#  'human-physics-benchmarking-containment-pilot_production_1',
#  'lax_reconstruction_stims_castle',
#  'lax_reconstruction_stims_city',
#  'curiophysion_stim_balance',
#  'zipping_3_counterbalanced_color',
#  'dominoes-pilot_example',
#  'lax_drawing_wheels_10',
#  'causaldraw_annotations_fix_disagreements',
#  'human-physics-benchmarking-drop-pilot_production_2',
#  'human-physics-benchmarking-rollingsliding-pilot_production_2',
#  'human-physics-benchmarkingpp-dominoes-pilot_production_2',
#  'environment_structuring_tan_arrangement_no_search',
#  'human-physics-benchmarking-collision-pilot_iteration_1',
#  'lax_reconstruction_stims_bridge',
#  'causaldraw_identification',
#  'ca_prior_elicitation_4_block_unique_silhouettes_categorization',
#  'human-physics-benchmarking-drop-pilot_production_1',
#  'human-physics-benchmarking-clothiness-pilot_production_2',
#  'graphical_conventions_object_annotation',
#  'human-physics-benchmarking-collision-pilot_production_1',
#  'curiotower-tdw',
#  'lax_structures_castle_10',
#  'photodraw2',
#  'curiophysion-drop-pilotv1_pilotv2',
#  'human-physics-benchmarking-gravity-pilot_example',
#  'human-physics-benchmarking-dominoes-pilot_iteration_2',
#  'graph_comprehension_benchmarking',
#  'human-physics-benchmarking-dominoes-redyellow-pilot_production_2',
#  'lax_structures_castle_10_top_up',
#  'semantic_parts_graphical_conventions',
#  'sketch_program_synthesis_human',
#  'lax_reconstruction_stims_dev',
#  'tools_for_block_construction_given_subgoals',
#  'curiophysion-drop_pilot_1',
#  'human-physics-benchmarking-rollingsliding-pilot_iteration_1',
#  'lax_drawing_nuts-bolts_10',
#  'human-physics-benchmarking-linking-pilot_production_1',
#  'kiddraw_annotations_objects_patching',
#  'part_annotations_group1',
#  'lax_structures_bridge_10',
#  'causaldraw_intervention_patching',
#  'block-construction-silhouette-exp02',
#  'human-physics-benchmarking-dominoes-pilot_example',
#  'kiddraw_annotations_objects',
#  'human-physics-benchmarking-dominoes-pilot_production_1',
#  'human-physics-benchmarkingpp-dominoes-pilot_production_1',
#  'human-physics-benchmarking-drop-pilot_iteration_1',
#  'lax_structures_bridge_all',
#  'human-physics-benchmarking-plusplus-dvtwo-dominoes-pilot_production_1',
#  'curiotower-tdw-height3Jitter3',
#  'partnaming_exemplar',
#  'lax_structures_city_10',
#  'lax_drawing_dials_10',
#  'human-physics-benchmarking-plusplus-dominoes-pilot_production_2',
#  'kiddraw_annotations_big_animals_patching',
#  'iternum_classification',
#  'iternum_classification_patching3',
#  'compositional-abstractions-prior-elicitation_example',
#  'lax_structures_house_10',
#  'ca_prior_elicitation_4_block_unique_silhouettes_procedural',
#  'lax_drawing_furniture_10',
#  'zipping_calibration_trials',
#  'graph-comprehension-benchmarking_demo',
#  'human-physics-benchmarking-linking-pilot_production_2',
#  'part_annotations',
#  'kiddraw_annotations_big_animals',
#  'environment_structuring_tan_arrangement',
#  'iternum2_recog',
#  'causaldraw_intervention',
#  'human-physics-benchmarking-collision-pilot_iteration_2',
#  'physics_continual_learning_human',
#  'human-physics-benchmarking-clothiness-pilot_production_1',
#  'iternum_classification_patching2',
#  'kiddraw_annotations',
#  'environment_structuring_tan_search_post_rt_spread',
#  'iternum_classification_patching',
#  'ca_prior_elicitation_4_block_unique_silhouettes',
#  'human-physics-benchmarking-rollingsliding-pilot_production_1',
#  'human-physics-benchmarking-containment-pilot_production_2',
#  'kiddraw_annotations_vehicles_patching',
#  'lax_structures_house_10_top_up',
#  'part_annotations_group4',
#  'zipping_3_counterbalanced_top_up',
#  'curiophysion_drop',
#  'kiddraw_annotations_small_animals_patching',
#  'lax_structures_house_all',
#  'human-physics-benchmarking-plusplus-dominoes-pilot_production_1',
#  'lax_structures_city_all',
#  'physics_trust_agent_study2',
#  'environment_structuring_tan_arrangement_no_search_rt_spread',
#  'lax_drawing_dials_all',
#  'block-construction-silhouette-exp01',
#  'graphical_conventions_semantic_mapping_spline_version_old',
#  'curiophysion-drop-pilotv1_pilotv1',
#  'svg_annotation_sketchpad_basic_allcats']

# %%
## BE EXTRA CAREFUL WITH THIS -- this is to drop records in the causaldraw_annotations collection, which is stored in
## in the db. Because all grads' records are stored in the stimuli db, we want to be extra careful with this!!!

#db.drop_collection('graph_comprehension_benchmarking')
# Out:
# {'ns': 'stimuli.graph_comprehension_benchmarking', 'nIndexesWas': 1, 'ok': 1.0}
